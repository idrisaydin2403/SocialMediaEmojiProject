# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("C:\\Users\\İdris Aydın\\Desktop\\Sleep_health_and_lifestyle_dataset.csv")
df
# Out:
#      Person ID  Gender  Age            Occupation  Sleep Duration  \
# 0            1    Male   27     Software Engineer             6.1
# 1            2    Male   28                Doctor             6.2
# 2            3    Male   28                Doctor             6.2
# 3            4    Male   28  Sales Representative             5.9
# 4            5    Male   28  Sales Representative             5.9
# ..         ...     ...  ...                   ...             ...
# 369        370  Female   59                 Nurse             8.1
# 370        371  Female   59                 Nurse             8.0
# 371        372  Female   59                 Nurse             8.1
# 372        373  Female   59                 Nurse             8.1
# 373        374  Female   59                 Nurse             8.1
#
#      Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                   6                       42             6   Overweight
# ...

# %%
df.columns
# Out:
# Index(['Person ID', 'Gender', 'Age', 'Occupation', 'Sleep Duration',
#        'Quality of Sleep', 'Physical Activity Level', 'Stress Level',
#        'BMI Category', 'Blood Pressure', 'Heart Rate', 'Daily Steps',
#        'Sleep Disorder'],
#       dtype='object')

# %%
df = df.drop(columns=['Gender','Occupation','BMI Category','Sleep Disorder'])
df
# Out:
#      Person ID  Age  Sleep Duration  Quality of Sleep  \
# 0            1   27             6.1                 6
# 1            2   28             6.2                 6
# 2            3   28             6.2                 6
# 3            4   28             5.9                 4
# 4            5   28             5.9                 4
# ..         ...  ...             ...               ...
# 369        370   59             8.1                 9
# 370        371   59             8.0                 9
# 371        372   59             8.1                 9
# 372        373   59             8.1                 9
# 373        374   59             8.1                 9
#
#      Physical Activity Level  Stress Level Blood Pressure  Heart Rate  \
# 0                         42             6         126/83          77
# 1                         60             8         125/80          75
# 2                         60             8         125/80          75
# ...

# %%
df.describe()
# Out:
#         Person ID         Age  Sleep Duration  Quality of Sleep  \
# count  374.000000  374.000000      374.000000        374.000000
# mean   187.500000   42.184492        7.132086          7.312834
# std    108.108742    8.673133        0.795657          1.196956
# min      1.000000   27.000000        5.800000          4.000000
# 25%     94.250000   35.250000        6.400000          6.000000
# 50%    187.500000   43.000000        7.200000          7.000000
# 75%    280.750000   50.000000        7.800000          8.000000
# max    374.000000   59.000000        8.500000          9.000000
#
#        Physical Activity Level  Stress Level  Heart Rate   Daily Steps
# count               374.000000    374.000000  374.000000    374.000000
# mean                 59.171123      5.385027   70.165775   6816.844920
# std                  20.830804      1.774526    4.135676   1617.915679
# min                  30.000000      3.000000   65.000000   3000.000000
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X = df[['Age']]
y = df[['Stress Level']]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
prediction = lr.predict(X_test)

# %%
plt.scatter(X_test, y_test, color = 'blue', label = 'True Values')
plt.plot(X_test, prediction, color = 'orange', label = 'Estimated Values')
plt.xlabel("\nAGE")
plt.ylabel("STRESS LEVEL\n")
plt.title("AGE - STRESS LEVEL GRAPH\n")
plt.legend()

plt.show()

# %%
X = df[['Sleep Duration']]
y = df[['Stress Level']]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
prediction = lr.predict(X_test)

# %%
plt.scatter(X_test, y_test, color = 'blue', label = 'True Values')
plt.plot(X_test, prediction, color = 'orange', label = 'Estimated Values')
plt.xlabel("\nSLEEP DURATION")
plt.ylabel("STRESS LEVEL\n")
plt.title("SLEEP DURATION - STRESS LEVEL GRAPH\n")
plt.legend()

plt.show()

# %%
X = df[['Quality of Sleep']]
y = df[['Stress Level']]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
prediction = lr.predict(X_test)

# %%
plt.scatter(X_test, y_test, color = 'blue', label = 'True Values')
plt.plot(X_test, prediction, color = 'orange', label = 'Estimated Values')
plt.xlabel("\nQUALITY OF SLEEP")
plt.ylabel("STRESS LEVEL\n")
plt.title("QUALITY OF SLEEP - STRESS LEVEL GRAPH\n")
plt.legend()

plt.show()

# %%
X = df[['Age', 'Sleep Duration', 'Quality of Sleep']]
y = df[['Stress Level']]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
prediction = lr.predict(X_test)

# %%
import seaborn as sns

sns.pairplot(df[['Age','Sleep Duration','Quality of Sleep','Stress Level']])
plt.show()
